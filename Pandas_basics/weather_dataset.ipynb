# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv")
df
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2/1/2008     19.5     22.4      15.6          6.2       0.0
# 1      2/2/2008     19.5     25.6       6.0          3.4       2.7
# 2      2/3/2008     21.6     24.5       6.6          2.4       0.1
# 3      2/4/2008     20.2     22.8      18.8          2.2       0.0
# 4      2/5/2008     19.7     25.7      77.4          4.8       0.0
# ...         ...      ...      ...       ...          ...       ...
# 3266  6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267  6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268  6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269  6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...

# %%
rows,columns=df.shape
columns
# Out:
# 22

# %%
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail(1)
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 3270           W             35          W          W  ...           73
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 3270           32       1018.6       1015.4         1         1      9.4
#
#       Temp3pm  RainToday  RainTomorrow
# 3270     18.8         No            No
#
# [1 rows x 22 columns]

# %%
df[2:5]
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 2       1016.7       1015.6         7         8     23.5     23.0        Yes
# 3       1014.2       1011.8         8         8     21.4     20.9        Yes
# 4       1008.3       1004.8         8         8     22.5     25.5        Yes
#
#    RainTomorrow
# 2           Yes
# 3           Yes
# 4           Yes
# ...

# %%
df[:]
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2/1/2008     19.5     22.4      15.6          6.2       0.0
# 1      2/2/2008     19.5     25.6       6.0          3.4       2.7
# 2      2/3/2008     21.6     24.5       6.6          2.4       0.1
# 3      2/4/2008     20.2     22.8      18.8          2.2       0.0
# 4      2/5/2008     19.7     25.7      77.4          4.8       0.0
# ...         ...      ...      ...       ...          ...       ...
# 3266  6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267  6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268  6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269  6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...

# %%
df.columns
# Out:
# Index(['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.Date#df['Date']
# Out:
# 0        2/1/2008
# 1        2/2/2008
# 2        2/3/2008
# 3        2/4/2008
# 4        2/5/2008
#           ...
# 3266    6/21/2017
# 3267    6/22/2017
# 3268    6/23/2017
# 3269    6/24/2017
# 3270    6/25/2017
# Name: Date, Length: 3271, dtype: object

# %%
df[['Date','MinTemp','Rainfall']]
# Out:
#            Date  MinTemp  Rainfall
# 0      2/1/2008     19.5      15.6
# 1      2/2/2008     19.5       6.0
# 2      2/3/2008     21.6       6.6
# 3      2/4/2008     20.2      18.8
# 4      2/5/2008     19.7      77.4
# ...         ...      ...       ...
# 3266  6/21/2017      8.6       0.0
# 3267  6/22/2017      9.3       0.0
# 3268  6/23/2017      9.4       0.0
# 3269  6/24/2017     10.1       0.0
# 3270  6/25/2017      7.6       0.0
#
# [3271 rows x 3 columns]

# %%
df['MinTemp'].std()
# Out:
# 4.554710399931853

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     14.877102    23.005564     3.342158     5.175787     7.168970
# std       4.554710     4.483752     9.917746     2.757684     3.815966
# min       4.300000    11.700000     0.000000     0.000000     0.000000
# 25%      11.000000    19.600000     0.000000     3.200000     4.250000
# 50%      14.900000    22.800000     0.000000     4.800000     8.300000
# 75%      18.800000    26.000000     1.400000     7.000000    10.200000
# max      27.600000    45.800000   119.400000    18.400000    13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    3271.000000   3271.000000   3271.000000  3271.000000  3271.000000
# mean       41.476307     15.077041     19.294405    68.243962    54.698563
# std        10.806951      7.043825      7.453331    15.086127    16.279241
# ...

# %%
df[df.MinTemp>18]
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2/1/2008     19.5     22.4      15.6          6.2       0.0
# 1      2/2/2008     19.5     25.6       6.0          3.4       2.7
# 2      2/3/2008     21.6     24.5       6.6          2.4       0.1
# 3      2/4/2008     20.2     22.8      18.8          2.2       0.0
# 4      2/5/2008     19.7     25.7      77.4          4.8       0.0
# ...         ...      ...      ...       ...          ...       ...
# 3181  3/27/2017     19.2     27.0       0.0          5.8      11.0
# 3182  3/28/2017     21.2     23.8       0.0          7.4       0.0
# 3183  3/29/2017     21.4     28.8       0.0          2.4       8.4
# 3184  3/30/2017     22.5     26.0       2.4          7.4       0.0
# 3210  4/25/2017     18.2     26.7       0.0          4.4       3.0
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...

# %%
df[df.MaxTemp==df.MaxTemp.max()]
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 1696  1/18/2013     21.7     45.8       0.0          9.0       8.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 1696           S             78          E          E  ...           62
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 1696           14       1002.9        997.9         0         3     28.9
#
#       Temp3pm  RainToday  RainTomorrow
# 1696     44.7         No            No
#
# [1 rows x 22 columns]

# %%
df[df.MaxTemp==df.MaxTemp.max()][['Date','MaxTemp']]
# Out:
#            Date  MaxTemp
# 1696  1/18/2013     45.8

# %%
df.set_index('Date')
# Out:
#            MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2/1/2008      19.5     22.4      15.6          6.2       0.0           W
# 2/2/2008      19.5     25.6       6.0          3.4       2.7           W
# 2/3/2008      21.6     24.5       6.6          2.4       0.1           W
# 2/4/2008      20.2     22.8      18.8          2.2       0.0           W
# 2/5/2008      19.7     25.7      77.4          4.8       0.0           W
# ...            ...      ...       ...          ...       ...         ...
# 6/21/2017      8.6     19.6       0.0          2.0       7.8         SSE
# 6/22/2017      9.3     19.2       0.0          2.0       9.2           W
# 6/23/2017      9.4     17.7       0.0          2.4       2.7           W
# 6/24/2017     10.1     19.3       0.0          1.4       9.3           W
# 6/25/2017      7.6     19.3       0.0          3.4       9.4           W
#
#            WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# ...

# %%
df.set_index('Date',inplace=True)
df
# Out:
#            MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# Date
# 2/1/2008      19.5     22.4      15.6          6.2       0.0           W
# 2/2/2008      19.5     25.6       6.0          3.4       2.7           W
# 2/3/2008      21.6     24.5       6.6          2.4       0.1           W
# 2/4/2008      20.2     22.8      18.8          2.2       0.0           W
# 2/5/2008      19.7     25.7      77.4          4.8       0.0           W
# ...            ...      ...       ...          ...       ...         ...
# 6/21/2017      8.6     19.6       0.0          2.0       7.8         SSE
# 6/22/2017      9.3     19.2       0.0          2.0       9.2           W
# 6/23/2017      9.4     17.7       0.0          2.4       2.7           W
# 6/24/2017     10.1     19.3       0.0          1.4       9.3           W
# 6/25/2017      7.6     19.3       0.0          3.4       9.4           W
#
#            WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  \
# ...

# %%
df.loc['6/24/2017']
# Out:
# MinTemp            10.1
# MaxTemp            19.3
# Rainfall            0.0
# Evaporation         1.4
# Sunshine            9.3
# WindGustDir           W
# WindGustSpeed        43
# WindDir9am            W
# WindDir3pm            W
# WindSpeed9am         17
# WindSpeed3pm         19
# Humidity9am          56
# Humidity3pm          35
# Pressure9am      1017.3
# Pressure3pm      1015.1
# Cloud9am              5
# Cloud3pm              2
# Temp9am            12.4
# Temp3pm            19.0
# RainToday            No
# RainTomorrow         No
# Name: 6/24/2017, dtype: object

# %%
df.reset_index(inplace=True)#default inplace=False
df
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2/1/2008     19.5     22.4      15.6          6.2       0.0
# 1      2/2/2008     19.5     25.6       6.0          3.4       2.7
# 2      2/3/2008     21.6     24.5       6.6          2.4       0.1
# 3      2/4/2008     20.2     22.8      18.8          2.2       0.0
# 4      2/5/2008     19.7     25.7      77.4          4.8       0.0
# ...         ...      ...      ...       ...          ...       ...
# 3266  6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267  6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268  6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269  6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...
