# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv",skiprows=1)#header=1
df
# Out:
#             Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     02-01-2008     19.5     22.4      15.6          6.2       0.0
# 1     02-02-2008     19.5     25.6       6.0          3.4       2.7
# 2     02-03-2008     21.6     24.5       6.6          2.4       0.1
# 3     02-04-2008     20.2     22.8      18.8          2.2       0.0
# 4     02-05-2008     19.7     25.7      77.4          4.8       0.0
# ...          ...      ...      ...       ...          ...       ...
# 3266   6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267   6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268   6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269   6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270   6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv",header=None,names=["Date","MinTemp","MaxTemp","Rainfall","Evaporation","Sunshine","WindGustDir","WindGustSpeed","WindDir9am","WindDir3pm","WindSpeed9am","WindSpeed3pm","Humidity9am","Humidity3pm","Pressure9am","Pressure3pm","Cloud9am","Cloud3pm","Temp9am","Temp3pm","RainToday","RainTomorrow"])
df
# Out:
#             Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     02-01-2008     19.5     22.4      15.6          6.2       0.0
# 1     02-02-2008     19.5     25.6       6.0          3.4       2.7
# 2     02-03-2008     21.6     24.5       6.6          2.4       0.1
# 3     02-04-2008     20.2     22.8      18.8          2.2       0.0
# 4     02-05-2008     19.7     25.7      77.4          4.8       0.0
# ...          ...      ...      ...       ...          ...       ...
# 3266   6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267   6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268   6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269   6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270   6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv",nrows=3)
df
# Out:
#          Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  02-01-2008     19.5     22.4      15.6          6.2       0.0           W
# 1  02-02-2008     19.5     25.6       6.0          3.4       2.7           W
# 2  02-03-2008     21.6     24.5       6.6          2.4       0.1           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1017.6       1017.4         8         8     20.7     20.9        Yes
# 1       1017.9       1016.4         7         7     22.4     24.8        Yes
# 2       1016.7       1015.6         7         8     23.5     23.0        Yes
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv",na_values=["N.A"])
df
# Out:
#             Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     02-01-2008     19.5     22.4      15.6          6.2       0.0
# 1     02-02-2008     19.5     25.6       6.0          3.4       2.7
# 2     02-03-2008     21.6     24.5       6.6          2.4       0.1
# 3     02-04-2008     20.2     22.8      18.8          2.2       0.0
# 4     02-05-2008     19.7     25.7      77.4          4.8       0.0
# ...          ...      ...      ...       ...          ...       ...
# 3266   6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267   6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268   6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269   6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270   6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W           41.0          S        SSW  ...           92
# ...

# %%
df.to_csv("new.csv",index=False)

# %%
df.columns
# Out:
# Index(['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.to_csv("new.csv",columns=["MinTemp","MaxTemp"])

# %%
df.to_csv("new.csv",header=False)

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv.xlsx","Weather_Data")
df
# Out:
#                      Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-01-02 00:00:00     19.5     22.4      15.6          6.2       0.0
# 1     2008-02-02 00:00:00     19.5     25.6       6.0          3.4       2.7
# 2     2008-03-02 00:00:00     21.6     24.5       6.6          2.4       0.1
# 3     2008-04-02 00:00:00     20.2     22.8      18.8          2.2       0.0
# 4     2008-05-02 00:00:00     19.7     25.7      77.4          4.8       0.0
# ...                   ...      ...      ...       ...          ...       ...
# 3266            6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267            6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268            6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269            6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270            6/25/2017      7.6     19.3       0.0          3.4       9.4
#
# ...

# %%
import pandas as pd
def convert_rainfall_cell(cell):
    if cell=="N.A":
        return 6
    else:
        return cell
def conert_windgustspeed_cell(cell):
    if cell=="N.A":
        return 41
    else:
        return cell
df=pd.read_excel("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv.xlsx","Weather_Data",converters={'Rainfall':convert_rainfall_cell,'WindGustSpeed':conert_windgustspeed_cell})
df
# Out:
#                      Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-01-02 00:00:00     19.5     22.4      15.6          6.2       0.0
# 1     2008-02-02 00:00:00     19.5     25.6       6.0          3.4       2.7
# 2     2008-03-02 00:00:00     21.6     24.5       6.6          2.4       0.1
# 3     2008-04-02 00:00:00     20.2     22.8      18.8          2.2       0.0
# 4     2008-05-02 00:00:00     19.7     25.7      77.4          4.8       0.0
# ...                   ...      ...      ...       ...          ...       ...
# 3266            6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267            6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268            6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269            6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270            6/25/2017      7.6     19.3       0.0          3.4       9.4
#
# ...

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\rheya_8e1lx53\\Projects\\Weather_Data.csv.xlsx")
df.to_excel("climate change.xlsx",sheet_name="Climate Changes",startcol=2,startrow=1)
